# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Malini\Downloads\Customer spent analysis.csv")

# %%
df
# Out:
#      Income  Spend
# 0       211    160
# 1       377    174
# 2       228    189
# 3       395    178
# 4       336    182
# ..      ...    ...
# 395     279    159
# 396     260    187
# 397     355    193
# 398     235    164
# 399     237    175
#
# [400 rows x 2 columns]

# %%
income=df["Income"].values
spend=df["Spend"].values
x=np.array(list(zip(income,spend)))
x
# Out:
# array([[211, 160],
#        [377, 174],
#        [228, 189],
#        [395, 178],
#        [336, 182],
#        [266, 185],
#        [211, 153],
#        [207, 177],
#        [367, 189],
#        [316, 163],
#        [367, 150],
#        [310, 153],
#        [315, 195],
#        [396, 184],
#        [275, 157],
#        [283, 166],
#        [399, 175],
#        [234, 150],
#        [336, 157],
#        [304, 195],
#        [343, 188],
#        [362, 183],
#        [211, 157],
#        [296, 168],
#        [345, 151],
#        [384, 158],
#        [308, 174],
#        [337, 173],
#        [376, 182],
#        [343, 172],
#        [311, 156],
#        [209, 158],
#        [207, 184],
#        [295, 160],
#        [269, 160],
#        [300, 160],
#        [253, 173],
#        [239, 172],
#        [263, 170],
#        [299, 199],
#        [306, 187],
#        [252, 192],
#        [336, 187],
#        [363, 172],
#        [344, 150],
#        [251, 162],
#        [365, 164],
# ...

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    km=KMeans(n_clusters=i,random_state=0)
    km.fit(x)
    wcss.append(km.inertia_)
plt.plot(range(1,11),wcss,color='blue',marker='*')
plt.title('optimal k values')
plt.xlabel('no/. of clusters')
plt.ylabel('wcss')
plt.show()

# %%
model=KMeans(n_clusters=4,random_state=0)
y_means=model.fit_predict(x)
y_means
# Out:
# array([0, 1, 0, 1, 3, 2, 0, 0, 1, 3, 1, 3, 3, 1, 2, 2, 1, 0, 3, 3, 3, 1,
#        0, 3, 3, 1, 3, 3, 1, 3, 3, 0, 0, 3, 2, 3, 2, 0, 2, 3, 3, 2, 3, 1,
#        3, 2, 1, 3, 1, 3, 0, 2, 2, 1, 0, 2, 3, 2, 3, 2, 3, 1, 0, 2, 1, 2,
#        1, 0, 1, 1, 3, 0, 1, 0, 0, 1, 3, 2, 3, 2, 3, 2, 0, 0, 1, 2, 3, 2,
#        2, 3, 3, 3, 2, 0, 0, 2, 2, 0, 2, 3, 1, 3, 1, 0, 0, 0, 2, 1, 3, 0,
#        0, 2, 3, 2, 3, 0, 2, 0, 0, 0, 3, 1, 2, 3, 3, 2, 3, 1, 2, 2, 3, 2,
#        2, 1, 2, 3, 1, 1, 1, 2, 3, 2, 3, 2, 0, 2, 1, 1, 0, 2, 2, 0, 2, 3,
#        3, 3, 2, 1, 2, 2, 3, 1, 0, 1, 2, 2, 2, 2, 0, 1, 2, 3, 3, 0, 3, 0,
#        3, 1, 3, 0, 0, 1, 0, 1, 3, 1, 1, 0, 0, 1, 0, 0, 2, 3, 3, 1, 2, 3,
#        0, 0, 2, 0, 3, 3, 3, 0, 1, 3, 1, 2, 3, 1, 2, 1, 3, 3, 0, 0, 3, 3,
#        3, 3, 1, 1, 2, 0, 2, 0, 2, 1, 1, 3, 2, 3, 2, 1, 1, 0, 1, 1, 0, 3,
#        1, 3, 3, 0, 3, 1, 3, 2, 2, 0, 1, 0, 1, 2, 1, 1, 0, 3, 2, 0, 0, 3,
#        0, 0, 1, 2, 1, 3, 2, 0, 3, 1, 0, 3, 1, 1, 3, 3, 2, 1, 3, 1, 2, 3,
# ...

# %%
plt.scatter(x[y_means==0,0],x[y_means==0,1],s=50,c='tomato',label='1')
plt.scatter(x[y_means==1,0],x[y_means==1,1],s=50,c='mediumorchid',label='2')
plt.scatter(x[y_means==2,0],x[y_means==2,1],s=50,c='mediumturquoise',label='3')
plt.scatter(x[y_means==3,0],x[y_means==3,1],s=50,c='greenyellow',label='4')
plt.scatter(model.cluster_centers_[:,0],model.cluster_centers_[:,1],s=100,marker='^',c='black')
plt.title('income spend analysis')
plt.xlabel('income')
plt.ylabel('spend')
plt.show()
